# %%
import pandas as pd

# %%
df = pd.read_csv("raw_fuel_prices_messy.csv") # Load csv file


print(df.head()) # prints first five lines

print(df.info()) # Checking missing values and datatypes at the same time.

print(df.isnull().sum()) # Checking missing values in each column 

print(df.describe()) # Prints basic statistics
# Out:
#          date  petrol_95  diesel
# 0  2024-01-03      22.87   21.42
# 1  2024-02-07        NaN   21.68
# 2  2024-03-06      23.49     NaN
# 3  2024-04-03      23.82   22.41
# 4         NaN      24.15   22.78
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       18 non-null     object
#  1   petrol_95  17 non-null     float64
#  2   diesel     17 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 584.0+ bytes
# None
# date         1
# petrol_95    2
# diesel       2
# dtype: int64
#        petrol_95     diesel
# count  17.000000  17.000000
# mean   25.331176  24.011176
# std     1.288050   1.416659
# min    22.870000  21.420000
# 25%    24.480000  23.140000
# 50%    25.410000  24.110000
# 75%    26.330000  25.070000
# max    27.250000  26.270000

# %%
# Drop row with missing date
df.dropna(subset=['date'], inplace=True)

# Calculate averages
avg_petrol = df['petrol_95'].mean()
avg_diesel = df['diesel'].mean()

# Fill missing values (correct pattern)
df['petrol_95'] = df['petrol_95'].fillna(avg_petrol)
df['diesel'] = df['diesel'].fillna(avg_diesel)

# Convert date
df['date'] = pd.to_datetime(df['date'])

# Verify
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 0 to 18
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       18 non-null     datetime64[ns]
#  1   petrol_95  18 non-null     float64
#  2   diesel     18 non-null     float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 576.0 bytes
# None
# date         0
# petrol_95    0
# diesel       0
# dtype: int64
